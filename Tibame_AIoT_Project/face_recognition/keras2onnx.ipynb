# %%
# !pip install tensorflow==2.2.0
# Out:
# ...
#      |████████████████████████████████| 516.2MB 28kB/s
# ...
#      |████████████████████████████████| 460kB 44.8MB/s
# ...
#      |████████████████████████████████| 3.0MB 29.6MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# ...

# %%
# !pip install keras2onnx
# Out:
# ...
#      |████████████████████████████████| 102kB 2.2MB/s
# ...
#      |████████████████████████████████| 81kB 6.7MB/s
# ...
#      |████████████████████████████████| 7.4MB 9.5MB/s
# ...
#      |████████████████████████████████| 71kB 7.7MB/s
# ...
#   Created wheel for fire: filename=fire-0.3.1-py2.py3-none-any.whl size=111005 sha256=75fcb99041b670bc1b96ff398c858652df0630a320eed54813d398d3f0d39ec3
#   Stored in directory: /root/.cache/pip/wheels/c1/61/df/768b03527bf006b546dce284eb4249b185669e65afc5fbb2ac
# Successfully built fire
# ...

# %%
model_folder_path = 'drive/My Drive/Tibame_AIoT_Project'
img_folder_path = 'drive/My Drive/Tibame_AIoT_Project/Datasets/cleandataset'
IMG_SIZE = 224

import tensorflow as tf
from tensorflow import keras
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.layers import Dense, Activation, Dropout, Flatten, Input, Convolution2D, ZeroPadding2D, MaxPooling2D, Activation
from keras.layers import Conv2D, AveragePooling2D, BatchNormalization
from keras.models import Model, Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from keras import metrics

from keras.models import load_model
import os

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.2.0
# 2.3.0-tf

# %%
# load keras model
#model = load_model(os.path.join(model_folder_path,'21_vggface_mlp128-8_2_save.h5'))
#model = load_model(os.path.join(model_folder_path,'23-1_vggface_mlp512-128_bs128save.h5'))
model = load_model(os.path.join(model_folder_path,"23-3_resnet_mlp512-128_bs64_ep1_0.6189_0.9524.h5"))

# %%
model.name
# Out:
# 'model_3'

# %%
# convert to onnx model
import keras2onnx
onnx_model = keras2onnx.convert_keras(model, model.name)
# Out:
# tf executing eager_mode: True
# tf.keras model eager_mode: False
# The ONNX operator number change on the optimization: 471 -> 137

# %%
temp_model_file = '23-3_resnet_mlp512-128_bs64_ep1.onnx'
keras2onnx.save_model(onnx_model, os.path.join(model_folder_path,temp_model_file))
